# %% [markdown]
# REQUIRED PACKAGES

# %%
import pandas as pd                           
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ADDING DATASET

# %%
dw_df=pd.read_csv("delhi.csv")

# %% [markdown]
# TOP 5 ROWS

# %%
dw_df.head(5)
# Out:
#              date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2009-01-01 00:00:00        22         9           0.0      8.7        4
# 1  2009-01-01 01:00:00        22         9           0.0      8.7        4
# 2  2009-01-01 02:00:00        22         9           0.0      8.7        4
# 3  2009-01-01 03:00:00        22         9           0.0      8.7        4
# 4  2009-01-01 04:00:00        22         9           0.0      8.7        4
#
#    uvIndex.1  moon_illumination  moonrise   moonset  ... WindChillC  \
# 0          1                 31  10:11 AM  09:57 PM  ...         14
# 1          1                 31  10:11 AM  09:57 PM  ...         13
# 2          1                 31  10:11 AM  09:57 PM  ...         12
# 3          1                 31  10:11 AM  09:57 PM  ...         11
# 4          1                 31  10:11 AM  09:57 PM  ...         11
#
#   WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %% [markdown]
# BOTTOM 5 ROWS

# %%
dw_df.tail(5)
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 96427  2020-01-01 19:00:00        19        10           0.0      8.7
# 96428  2020-01-01 20:00:00        19        10           0.0      8.7
# 96429  2020-01-01 21:00:00        19        10           0.0      8.7
# 96430  2020-01-01 22:00:00        19        10           0.0      8.7
# 96431  2020-01-01 23:00:00        19        10           0.0      8.7
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# 96427        5          1                 37  11:28 AM  11:12 PM  ...
# 96428        5          1                 37  11:28 AM  11:12 PM  ...
# 96429        5          1                 37  11:28 AM  11:12 PM  ...
# 96430        5          1                 37  11:28 AM  11:12 PM  ...
# 96431        5          1                 37  11:28 AM  11:12 PM  ...
#
#       WindChillC WindGustKmph  cloudcover  humidity  precipMM  pressure  \
# ...

# %% [markdown]
# DATA INFO

# %%
dw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96432 entries, 0 to 96431
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          96432 non-null  object
#  1   maxtempC           96432 non-null  int64
#  2   mintempC           96432 non-null  int64
#  3   totalSnow_cm       96432 non-null  float64
#  4   sunHour            96432 non-null  float64
#  5   uvIndex            96432 non-null  int64
#  6   uvIndex.1          96432 non-null  int64
#  7   moon_illumination  96432 non-null  int64
#  8   moonrise           96432 non-null  object
#  9   moonset            96432 non-null  object
#  10  sunrise            96432 non-null  object
#  11  sunset             96432 non-null  object
#  12  DewPointC          96432 non-null  int64
#  13  FeelsLikeC         96432 non-null  int64
#  14  HeatIndexC         96432 non-null  int64
#  15  WindChillC         96432 non-null  int64
# ...

# %% [markdown]
# CHECKING FOR NULL ENTRIES

# %%
dw_df.isna().sum()
# Out:
# date_time            0
# maxtempC             0
# mintempC             0
# totalSnow_cm         0
# sunHour              0
# uvIndex              0
# uvIndex.1            0
# moon_illumination    0
# moonrise             0
# moonset              0
# sunrise              0
# sunset               0
# DewPointC            0
# FeelsLikeC           0
# HeatIndexC           0
# WindChillC           0
# WindGustKmph         0
# cloudcover           0
# humidity             0
# precipMM             0
# pressure             0
# tempC                0
# visibility           0
# winddirDegree        0
# windspeedKmph        0
# dtype: int64

# %% [markdown]
# CHECKING FOR UNIQUE VALUES

# %%
dw_df.nunique(axis=0)
# Out:
# date_time            96432
# maxtempC                39
# mintempC                43
# totalSnow_cm             1
# sunHour                 62
# uvIndex                  9
# uvIndex.1               11
# moon_illumination      101
# moonrise              1331
# moonset               1360
# sunrise                114
# sunset                 120
# DewPointC               48
# FeelsLikeC              61
# HeatIndexC              60
# WindChillC              51
# WindGustKmph            65
# cloudcover             101
# humidity                99
# precipMM                88
# pressure                39
# tempC                   52
# visibility              21
# winddirDegree          361
# windspeedKmph           42
# dtype: int64

# %%
dw_df
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2009-01-01 00:00:00        22         9           0.0      8.7
# 1      2009-01-01 01:00:00        22         9           0.0      8.7
# 2      2009-01-01 02:00:00        22         9           0.0      8.7
# 3      2009-01-01 03:00:00        22         9           0.0      8.7
# 4      2009-01-01 04:00:00        22         9           0.0      8.7
# ...                    ...       ...       ...           ...      ...
# 96427  2020-01-01 19:00:00        19        10           0.0      8.7
# 96428  2020-01-01 20:00:00        19        10           0.0      8.7
# 96429  2020-01-01 21:00:00        19        10           0.0      8.7
# 96430  2020-01-01 22:00:00        19        10           0.0      8.7
# 96431  2020-01-01 23:00:00        19        10           0.0      8.7
#
#        uvIndex  uvIndex.1  moon_illumination  moonrise   moonset  ...  \
# ...

# %% [markdown]
# SINCE "date_time" HAS ALL UNIQUE VALUE THEREFORE SETTING IT AS THE INDEX

# %%
dw_df.set_index("date_time")
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2009-01-01 00:00:00        22         9           0.0      8.7        4
# 2009-01-01 01:00:00        22         9           0.0      8.7        4
# 2009-01-01 02:00:00        22         9           0.0      8.7        4
# 2009-01-01 03:00:00        22         9           0.0      8.7        4
# 2009-01-01 04:00:00        22         9           0.0      8.7        4
# ...                       ...       ...           ...      ...      ...
# 2020-01-01 19:00:00        19        10           0.0      8.7        5
# 2020-01-01 20:00:00        19        10           0.0      8.7        5
# 2020-01-01 21:00:00        19        10           0.0      8.7        5
# 2020-01-01 22:00:00        19        10           0.0      8.7        5
# 2020-01-01 23:00:00        19        10           0.0      8.7        5
#
#                      uvIndex.1  moon_illumination  moonrise   moonset  \
# date_time
# ...

# %% [markdown]
# CHECKING THE SIZE AND COLUMN NAME

# %%
dw_df.shape #columns is still 25 that means need to change index in csv
# Out:
# (96432, 25)

# %%
dw_df=pd.read_csv("delhi.csv", parse_dates=["date_time"],index_col="date_time") #setting datetime format and it as index

# %%
dw_df
# Out:
#                      maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# date_time
# 2009-01-01 00:00:00        22         9           0.0      8.7        4
# 2009-01-01 01:00:00        22         9           0.0      8.7        4
# 2009-01-01 02:00:00        22         9           0.0      8.7        4
# 2009-01-01 03:00:00        22         9           0.0      8.7        4
# 2009-01-01 04:00:00        22         9           0.0      8.7        4
# ...                       ...       ...           ...      ...      ...
# 2020-01-01 19:00:00        19        10           0.0      8.7        5
# 2020-01-01 20:00:00        19        10           0.0      8.7        5
# 2020-01-01 21:00:00        19        10           0.0      8.7        5
# 2020-01-01 22:00:00        19        10           0.0      8.7        5
# 2020-01-01 23:00:00        19        10           0.0      8.7        5
#
#                      uvIndex.1  moon_illumination  moonrise   moonset  \
# date_time
# ...

# %%
dw_df.columns   #24 columns
# Out:
# Index(['maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
#        'uvIndex.1', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC',
#        'WindGustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirDegree', 'windspeedKmph'],
#       dtype='object')

# %% [markdown]
# INFO ABOUT EACH COLUMN

# %%
dw_df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  96432.000000  96432.000000       96432.0  96432.000000  96432.000000
# mean      32.681434     21.505475           0.0     11.213489      6.736685
# std        7.479931      8.245626           0.0      2.155831      1.656212
# min       12.000000      1.000000           0.0      3.800000      3.000000
# 25%       26.000000     14.000000           0.0      8.700000      5.000000
# 50%       34.000000     23.000000           0.0     11.600000      7.000000
# 75%       38.000000     28.000000           0.0     13.200000      8.000000
# max       52.000000     43.000000           0.0     14.000000     11.000000
#
#           uvIndex.1  moon_illumination     DewPointC    FeelsLikeC  \
# count  96432.000000       96432.000000  96432.000000  96432.000000
# mean       4.390316          46.094077     12.170929     30.486270
# std        3.372834          31.249725      8.049545      9.853813
# ...

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# CHOOSING AND SEPERATING COLUMNS TO BE USED

# %%
dw_df_num=dw_df.loc[:,['maxtempC', 'mintempC', 'sunHour', 'HeatIndexC', 'cloudcover', 'humidity', 'precipMM', 'pressure',
       'tempC', 'windspeedKmph']] #feature engineering

# %%
dw_df_num.head()
# Out:
#                      maxtempC  mintempC  sunHour  HeatIndexC  cloudcover  \
# date_time
# 2009-01-01 00:00:00        22         9      8.7          14           0
# 2009-01-01 01:00:00        22         9      8.7          14           0
# 2009-01-01 02:00:00        22         9      8.7          13           0
# 2009-01-01 03:00:00        22         9      8.7          13           0
# 2009-01-01 04:00:00        22         9      8.7          13           2
#
#                      humidity  precipMM  pressure  tempC  windspeedKmph
# date_time
# 2009-01-01 00:00:00        50       0.0      1016     10             12
# 2009-01-01 01:00:00        51       0.0      1016     10             13
# 2009-01-01 02:00:00        52       0.0      1016      9             13
# 2009-01-01 03:00:00        54       0.0      1016      9             13
# 2009-01-01 04:00:00        52       0.0      1016      9             13

# %% [markdown]
# SIZE OF NEW DATAFRAME

# %%
dw_df_num.shape
# Out:
# (96432, 10)

# %%
dw_df_num.plot(subplots=True, figsize=(10,5))
# Out:
# array([<AxesSubplot:xlabel='date_time'>, <AxesSubplot:xlabel='date_time'>,
#        <AxesSubplot:xlabel='date_time'>, <AxesSubplot:xlabel='date_time'>,
#        <AxesSubplot:xlabel='date_time'>, <AxesSubplot:xlabel='date_time'>,
#        <AxesSubplot:xlabel='date_time'>, <AxesSubplot:xlabel='date_time'>,
#        <AxesSubplot:xlabel='date_time'>, <AxesSubplot:xlabel='date_time'>],
#       dtype=object)

# %%
dw_df_num.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'maxtempC'}>,
#         <AxesSubplot:title={'center':'mintempC'}>,
#         <AxesSubplot:title={'center':'sunHour'}>],
#        [<AxesSubplot:title={'center':'HeatIndexC'}>,
#         <AxesSubplot:title={'center':'cloudcover'}>,
#         <AxesSubplot:title={'center':'humidity'}>],
#        [<AxesSubplot:title={'center':'precipMM'}>,
#         <AxesSubplot:title={'center':'pressure'}>,
#         <AxesSubplot:title={'center':'tempC'}>],
#        [<AxesSubplot:title={'center':'windspeedKmph'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# VALUES FROM 2019 TO 2020

# %%
weather=dw_df_num['2019':'2020']

# %%
weather.head()
# Out:
#                      maxtempC  mintempC  sunHour  HeatIndexC  cloudcover  \
# date_time
# 2019-01-01 00:00:00        23        18      8.7          20           0
# 2019-01-01 01:00:00        23        18      8.7          20           0
# 2019-01-01 02:00:00        23        18      8.7          20           0
# 2019-01-01 03:00:00        23        18      8.7          19           0
# 2019-01-01 04:00:00        23        18      8.7          19           0
#
#                      humidity  precipMM  pressure  tempC  windspeedKmph
# date_time
# 2019-01-01 00:00:00        30       0.0      1020     20              6
# 2019-01-01 01:00:00        31       0.0      1020     20              6
# 2019-01-01 02:00:00        31       0.0      1020     20              6
# 2019-01-01 03:00:00        31       0.0      1020     19              6
# 2019-01-01 04:00:00        32       0.0      1020     19              6

# %%
weather.tail()
# Out:
#                      maxtempC  mintempC  sunHour  HeatIndexC  cloudcover  \
# date_time
# 2020-01-01 19:00:00        19        10      8.7          17          10
# 2020-01-01 20:00:00        19        10      8.7          16           9
# 2020-01-01 21:00:00        19        10      8.7          16           8
# 2020-01-01 22:00:00        19        10      8.7          15           8
# 2020-01-01 23:00:00        19        10      8.7          15           7
#
#                      humidity  precipMM  pressure  tempC  windspeedKmph
# date_time
# 2020-01-01 19:00:00        39       0.0      1020     17              9
# 2020-01-01 20:00:00        40       0.0      1021     16              8
# 2020-01-01 21:00:00        41       0.0      1021     16              8
# 2020-01-01 22:00:00        42       0.0      1021     15              8
# 2020-01-01 23:00:00        42       0.0      1022     15              8

# %%
w_y=dw_df_num.pop("tempC")
w_x=dw_df_num

# %% [markdown]
# SPLITTING OF DATASET INTO TRAINING AND TESTING

# %%
train_x,test_x,train_y,test_y=train_test_split(w_x,w_y,test_size=0.2,random_state=4)

# %% [markdown]
# train_x:all columns(features) except temperature column
# train_y:temperature value for all columns(features)

# %%
train_x.shape
# Out:
# (77145, 9)

# %%
train_y.shape
# Out:
# (77145,)

# %%
train_y.head()
# Out:
# date_time
# 2012-03-13 07:00:00    17
# 2009-11-05 21:00:00    18
# 2017-10-11 22:00:00    29
# 2019-06-08 11:00:00    47
# 2019-03-06 05:00:00    20
# Name: tempC, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
plt.scatter(weather.mintempC,weather.tempC)             # weather contains data from 2019-2020
plt.xlabel("min temp in C")
plt.ylabel("temp in C")
plt.show()

# %%
plt.scatter(weather.humidity,weather.tempC)              # weather contains data from 2019-2020
plt.xlabel("humidity")
plt.ylabel("temp in C")
plt.show()

# %%
plt.scatter(weather.windspeedKmph,weather.tempC)          # weather contains data from 2019-2020
plt.xlabel("windspeedKmph")
plt.ylabel("temp in C")
plt.show()

# %%
plt.scatter(weather.precipMM,weather.tempC)                  # weather contains data from 2019-2020
plt.xlabel("precipitation in mm")
plt.ylabel("temp in C")
plt.show()

# %%
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
prediction=model.predict(test_x)

# %%
np.mean(np.absolute(prediction-test_y))                              #error calculation
# Out:
# 1.3091117503640022

# %%
print('variance: %0.2f' % model.score(test_x,test_y))                #variance calculation
# Out:
# variance: 0.96

# %%
for i in range(len(prediction)):
    prediction[i]=round(prediction[i],2)
pd.DataFrame({'actual':test_y,'predicted':prediction,'dif':(test_y-prediction)})
# Out:
#                      actual  predicted   dif
# date_time
# 2013-07-10 08:00:00      34      34.80 -0.80
# 2015-11-04 20:00:00      25      23.51  1.49
# 2015-09-21 09:00:00      32      31.60  0.40
# 2017-02-16 11:00:00      28      25.57  2.43
# 2012-07-21 01:00:00      29      29.43 -0.43
# ...                     ...        ...   ...
# 2019-03-30 09:00:00      34      30.43  3.57
# 2015-11-12 12:00:00      30      27.79  2.21
# 2019-12-31 05:00:00      14      12.40  1.60
# 2019-08-02 17:00:00      37      37.33 -0.33
# 2019-10-22 08:00:00      31      28.09  2.91
#
# [19287 rows x 3 columns]

# %% [markdown]
# DECISION TREE REGRESSION

# %%
from sklearn.tree import DecisionTreeRegressor
reg=DecisionTreeRegressor(random_state=0)
reg.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
prediction1=reg.predict(test_x)

# %%
np.mean(np.absolute(prediction1-test_y))                              #error calculation
# Out:
# 0.6313838336703479

# %%
print('variance: %0.2f' % reg.score(test_x,test_y))                   #variance calculation
# Out:
# variance: 0.98

# %%
for i in range(len(prediction1)):
    prediction1[i]=round(prediction1[i],2)
pd.DataFrame({'actual':test_y,'predicted':prediction1,'dif':(test_y-prediction1)})
# Out:
#                      actual  predicted  dif
# date_time
# 2013-07-10 08:00:00      34       34.0  0.0
# 2015-11-04 20:00:00      25       26.0 -1.0
# 2015-09-21 09:00:00      32       33.0 -1.0
# 2017-02-16 11:00:00      28       28.0  0.0
# 2012-07-21 01:00:00      29       29.0  0.0
# ...                     ...        ...  ...
# 2019-03-30 09:00:00      34       34.0  0.0
# 2015-11-12 12:00:00      30       29.0  1.0
# 2019-12-31 05:00:00      14       14.0  0.0
# 2019-08-02 17:00:00      37       37.0  0.0
# 2019-10-22 08:00:00      31       32.0 -1.0
#
# [19287 rows x 3 columns]

# %% [markdown]
# RANDOM FOREST REGRESSION

# %%
from sklearn.ensemble import RandomForestRegressor
regrf=RandomForestRegressor(max_depth=90,random_state=0,n_estimators=100)
regrf.fit(train_x,train_y)
# Out:
# RandomForestRegressor(max_depth=90, random_state=0)

# %%
prediction2=regrf.predict(test_x)

# %%
np.mean(np.absolute(prediction2-test_y))                                #error calculation
# Out:
# 0.5188810874074913

# %%
print('variance: %0.2f' % regrf.score(test_x,test_y))                   #variance calculation
# Out:
# variance: 0.99

# %%
for i in range(len(prediction2)):
    prediction2[i]=round(prediction2[i],2)
pd.DataFrame({'actual':test_y,'predicted':prediction2,'dif':(test_y-prediction2)})
# Out:
#                      actual  predicted   dif
# date_time
# 2013-07-10 08:00:00      34      33.98  0.02
# 2015-11-04 20:00:00      25      25.34 -0.34
# 2015-09-21 09:00:00      32      32.04 -0.04
# 2017-02-16 11:00:00      28      28.05 -0.05
# 2012-07-21 01:00:00      29      29.10 -0.10
# ...                     ...        ...   ...
# 2019-03-30 09:00:00      34      32.67  1.33
# 2015-11-12 12:00:00      30      29.01  0.99
# 2019-12-31 05:00:00      14      13.56  0.44
# 2019-08-02 17:00:00      37      37.02 -0.02
# 2019-10-22 08:00:00      31      30.28  0.72
#
# [19287 rows x 3 columns]

# %% [markdown]
# CALCULATING R2 SCORE

# %%
from sklearn.metrics import r2_score

# %%
#MLR
print("mean absolute error : %.2f" % np.mean(np.absolute(prediction-test_y)))                     
print("residual sum of squares (RSS) : %.2f" % np.mean((prediction-test_y)**2))
print("R2 score : %.2f" % r2_score(test_y,prediction))
# Out:
# mean absolute error : 1.31
# residual sum of squares (RSS) : 3.11
# R2 score : 0.96

# %%
#DTR
print("mean absolute error : %.2f" % np.mean(np.absolute(prediction1-test_y)))
print("residual sum of squares (RSS) : %.2f" % np.mean((prediction1-test_y)**2))
print("R2 score : %.2f" % r2_score(test_y,prediction1))
# Out:
# mean absolute error : 0.63
# residual sum of squares (RSS) : 1.26
# R2 score : 0.98

# %%
#RFR
print("mean absolute error : %.2f" % np.mean(np.absolute(prediction2-test_y)))
print("residual sum of squares (RSS) : %.2f" % np.mean((prediction2-test_y)**2))
print("R2 score : %.2f" % r2_score(test_y,prediction2))
# Out:
# mean absolute error : 0.52
# residual sum of squares (RSS) : 0.73
# R2 score : 0.99
